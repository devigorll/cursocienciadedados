# %% [markdown]
# <a href="https://colab.research.google.com/github/devigorll/cursocienciadedados/blob/main/projeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os

# %%
import kagglehub
path = kagglehub.dataset_download("fabioschirmann/brasileiro-2024-srie-a-dataset")

# Lista os arquivos da pasta
arquivos = os.listdir(path)
print(arquivos)

# Exemplo: pegar o primeiro arquivo CSV encontrado
arquivo_csv = [arq for arq in arquivos if arq.endswith(".csv")][0]

# Caminho completo do arquivo
caminho_arquivo = os.path.join(path, arquivo_csv)

# Ler o dataset
df = pd.read_csv(caminho_arquivo)
df
# Out:
# Using Colab cache for faster access to the 'brasileiro-2024-srie-a-dataset' dataset.
# ['Brasileiro 2024 (Srie A) - Dataset - Final.csv', 'Brasileiro 2024 (Srie A) - Dataset.csv']
#      2024-04-13  18:30          Criciúma  1–1         Juventude  12,804  \
# 0    2024-04-13  18:30     Internacional  2–1             Bahia  19,103
# 1    2024-04-14  16:00    Ath Paranaense  4–0            Cuiabá  21,388
# 2    2024-04-14  16:00     Vasco da Gama  2–1            Grêmio  17,722
# 3    2024-04-14  16:00       Corinthians  0–0  Atlético Mineiro  44,285
# 4    2024-04-14  16:00    Atl Goianiense  1–2          Flamengo  31,617
# ..          ...    ...               ...  ...               ...     ...
# 374  2024-12-08  16:00            Grêmio  0–3       Corinthians  42,945
# 375  2024-12-08  16:00         Palmeiras  0–1        Fluminense  34,571
# 376  2024-12-08  16:00             Bahia  2–0    Atl Goianiense  48,476
# 377  2024-12-08  16:00         Juventude  0–1          Cruzeiro  13,518
# 378  2024-12-08  16:00  Atlético Mineiro  1–0    Ath Paranaense     NaN
#
#                    Estádio Heriberto Hülse
# 0              Estádio José Pinheiro Borba
# 1                              Ligga Arena
# 2    Estádio Club de Regatas Vasco da Gama
# 3                        Neo Química Arena
# 4    Estádio do Governo do Estado de Goiás
# ..                                     ...
# 374                        Arena do Grêmio
# 375                         Allianz Parque
# 376              Itaipava Arena Fonte Nova
# 377                 Estádio Alfredo Jaconi
# 378                              Arena MRV
#
# [379 rows x 7 columns]

# %%
# Instalando a biblioteca na minha máquina virtual

# !pip install -q streamlit
# !npm install -g localtunnel

# %%
ip = !wget -qO- ipv4.icanhazip.com
print(f"IP de acesso a págona Web: {ip[0]}")
# Out:
# IP de acesso a págona Web: 35.188.230.89

# %%
# %%writefile app.py
import streamlit as st

st.title("Olá Igor")
# Out:
# Overwriting app.py
